# %%
import os
import matplotlib.pyplot as plt
import geopandas as gpd
import earthpy as et
import matplotlib.pyplot as plt

# %%
data = gpd.read_file("C:/src/Python/DataVisualizationProjects/Historical Maps/WW2 Countries Shape File/cshapes.shp")
# fig = data.plot(figsize=(15, 15), cmap="Spectral").figure
# fig.savefig("main.png", dpi=900, quality=100)
# dir(data)

# %%
# year = 1950
# df = data[((data["COWSYEAR"] <= year)|(data["GWSYEAR"] <= year)) & ((data["GWEYEAR"] >= year)|(data["COWEYEAR"] >= year))]
# fig = df.plot(figsize=(8, 8), cmap="Spectral")

# %%
existing = []
for root, dirs, files in os.walk("./years"):
    for filename in files:
        existing.append("years/"+filename)
existing[:4]
# Out:
# ['years/1946.png', 'years/1947.png', 'years/1948.png', 'years/1949.png']

# %%
data.explode()
# Out:
#                   CNTRY_NAME          AREA        CAPNAME   CAPLONG  \
# 0   0                 Guyana  2.119820e+05     Georgetown -58.20000
# 1   0               Suriname  1.459523e+05     Paramaribo -55.20000
# 2   0    Trinidad and Tobago  5.041729e+03  Port-of-Spain -61.50000
#     1    Trinidad and Tobago  5.041729e+03  Port-of-Spain -61.50000
# 3   0              Venezuela  9.167822e+05        Caracas -66.90000
# ...                      ...           ...            ...       ...
# 254 127                 USSR  1.694295e+07         Moscow  37.61555
#     128                 USSR  1.694295e+07         Moscow  37.61555
#     129                 USSR  1.694295e+07         Moscow  37.61555
#     130                 USSR  1.694295e+07         Moscow  37.61555
#     131                 USSR  1.694295e+07         Moscow  37.61555
#
#             CAPLAT  FEATUREID  COWCODE  COWSYEAR  COWSMONTH  COWSDAY  ...  \
# 0   0     6.800000          0      110      1966          5       26  ...
# ...

# %%
base = "years/"
for year in range(1946, 2016):
    filename = base + str(year)+".png"
    if filename not in existing:
        print(filename)
        df = data[((data["COWSYEAR"] <= year)|(data["GWSYEAR"] <= year)) & ((data["GWEYEAR"] >= year)|(data["COWEYEAR"] >= year))]
        fig = df.plot(figsize=(8, 8), cmap="Spectral").figure 
        fig.savefig(filename, dpi=1000, quality=100)
# Out:
# years/1994.png
# years/2002.png
# years/2012.png
# years/2013.png
# years/2014.png
# years/2015.png

# %%
df = data[data["CNTRY_NAME"] == "Russia"]
fig = df.plot(figsize=(8, 8)).figure
fig.savefig("images/Russia1991.png", dpi=900, quality=100)

# %%
for i, row in data.iterrows():
    if row["COWSYEAR"] == -1:
        row["COWSYEAR"] = row["GWEYEAR"]
        data.iloc[i] = row

# %%
data.describe()
# Out:
#                AREA     CAPLONG      CAPLAT   FEATUREID     COWCODE  \
# count  2.550000e+02  255.000000  255.000000  255.000000  255.000000
# mean   1.583208e+06   25.402307   20.920010  127.682353  470.988235
# std    4.326390e+06   60.968525   23.962463   74.203945  264.448520
# min    9.275837e+00 -175.000000  -41.300000    0.000000   -1.000000
# 25%    3.583481e+04    1.558334    4.866667   63.500000  312.500000
# 50%    2.119820e+05   25.911950   18.539200  128.000000  475.000000
# 75%    9.264588e+05   46.772780   41.526250  191.500000  674.000000
# max    2.200891e+07  179.000000   64.150000  256.000000  990.000000
#
#           COWSYEAR   COWSMONTH     COWSDAY     COWEYEAR   COWEMONTH  \
# count   255.000000  255.000000  255.000000   255.000000  255.000000
# mean   1966.843137    5.411765    9.713725  1936.968627    5.807843
# std      18.745469    4.061421   10.060467   371.815930    1.991700
# min    1946.000000   -1.000000   -1.000000    -1.000000   -1.000000
# ...

# %%
# russ = data[(data["CNTRY_NAME"] == "USSR") | (data["CNTRY_NAME"] == "Russia")]
# dir(russ)
#russ.plot(figsize=(40, 4))

# %%
changes = data[data.groupby('CNTRY_NAME')['CNTRY_NAME'].transform('size') > 1]
changes.count()[0]
# Out:
# 74

# %%
existing = []
for root, dirs, files in os.walk("./images"):
    for filename in files:
        existing.append("images/"+filename)

# %%
for i, row in changes.iterrows():
    filename = "images/"+row["CNTRY_NAME"]+str(row["COWSYEAR"])+" - "+str(row["CAPLAT"])+".png"
    if filename not in existing:
        df = changes[(changes["CNTRY_NAME"] == row["CNTRY_NAME"]) & (changes["AREA"] == row["AREA"])]
        fig = df.plot(figsize=(8, 8)).figure
        fig.savefig(filename, dpi=900, quality=100)
        fig.clear()
        plt.close(fig)

# %%
# dir(russ)
# russ.explode()
# Out:
#         CNTRY_NAME          AREA CAPNAME   CAPLONG    CAPLAT  FEATUREID  \
# 64  0       Russia  1.682720e+07  Moscow  37.61555  55.75222         65
#     1       Russia  1.682720e+07  Moscow  37.61555  55.75222         65
#     2       Russia  1.682720e+07  Moscow  37.61555  55.75222         65
#     3       Russia  1.682720e+07  Moscow  37.61555  55.75222         65
#     4       Russia  1.682720e+07  Moscow  37.61555  55.75222         65
# ...            ...           ...     ...       ...       ...        ...
# 254 127       USSR  1.694295e+07  Moscow  37.61555  55.75222        256
#     128       USSR  1.694295e+07  Moscow  37.61555  55.75222        256
#     129       USSR  1.694295e+07  Moscow  37.61555  55.75222        256
#     130       USSR  1.694295e+07  Moscow  37.61555  55.75222        256
#     131       USSR  1.694295e+07  Moscow  37.61555  55.75222        256
#
#          COWCODE  COWSYEAR  COWSMONTH  COWSDAY  ...  GWSMONTH  GWSDAY  \
# ...
